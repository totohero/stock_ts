# %%
from pykrx import stock

sectors = stock.get_index_ticker_list()

sectors

sector_map = [(sector, stock.get_index_ticker_name(sector)) for sector in sectors]
sector_map
# Out:
# [('1001', '코스피'),
#  ('1002', '코스피 대형주'),
#  ('1003', '코스피 중형주'),
#  ('1004', '코스피 소형주'),
#  ('1005', '음식료품'),
#  ('1006', '섬유의복'),
#  ('1007', '종이목재'),
#  ('1008', '화학'),
#  ('1009', '의약품'),
#  ('1010', '비금속광물'),
#  ('1011', '철강금속'),
#  ('1012', '기계'),
#  ('1013', '전기전자'),
#  ('1014', '의료정밀'),
#  ('1015', '운수장비'),
#  ('1016', '유통업'),
#  ('1017', '전기가스업'),
#  ('1018', '건설업'),
#  ('1019', '운수창고업'),
#  ('1020', '통신업'),
#  ('1021', '금융업'),
#  ('1024', '증권'),
#  ('1025', '보험'),
#  ('1026', '서비스업'),
#  ('1027', '제조업'),
#  ('1028', '코스피 200'),
#  ('1034', '코스피 100'),
#  ('1035', '코스피 50'),
#  ('1150', '코스피 200 커뮤니케이션서비스'),
#  ('1151', '코스피 200 건설'),
#  ('1152', '코스피 200 중공업'),
#  ('1153', '코스피 200 철강/소재'),
#  ('1154', '코스피 200 에너지/화학'),
#  ('1155', '코스피 200 정보기술'),
#  ('1156', '코스피 200 금융'),
#  ('1157', '코스피 200 생활소비재'),
#  ('1158', '코스피 200 경기소비재'),
#  ('1159', '코스피 200 산업재'),
#  ('1160', '코스피 200 헬스케어'),
#  ('1167', '코스피 200 중소형주'),
#  ('1182', '코스피 200 초대형제외 지수'),
# ...
